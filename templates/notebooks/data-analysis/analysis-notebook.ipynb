# %% [markdown]
# # Automatic Dev Data Analysis Template
#
# This notebook provides a structured starting point for exploratory data analysis.

# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = "retina"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# %%
# Load data
DATA_PATH = "data/raw/data.csv"
df = pd.read_csv(DATA_PATH)
df.head()

# %%
# Summary statistics
df.describe()
